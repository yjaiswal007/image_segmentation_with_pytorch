# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Path to your folder inside Google Drive
folder_path = '/content/drive/My Drive/Colab_Notebooks/'

# Change working directory to that folder
os.chdir(folder_path)

# Confirm path
# !pwd
# Out:
# /content/drive/My Drive/Colab_Notebooks

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Colab_Notebooks/.git/

# %%
# !git config --global user.name "yjaiswal007"
# !git config --global user.email "yjaiswal007@gmail.com"

# %%
# !git add Image_segmentation.ipynb
# !git commit -m "Initial commit from Colab"
# Out:
# fatal: pathspec 'Image_segmentation.ipynb' did not match any files
# On branch master
#
# Initial commit
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	AzureML/
# 	Deep_learning_for_visual_computing/
# 	Finance/
# 	Git_drive_mount
# 	Image_segmentation_with_pytorch/
# 	MLflow_practice.ipynb
# 	Mnist_practice.ipynb
# 	OpenAI/
# 	PyTorch_practice.ipynb
# 	Pyspark_revision
# 	Pythorch_practice_1.ipynb
# 	RAG_exp/
# 	Stocks/
# 	Untitled0.ipynb
# 	Untitled1.ipynb
# 	Untitled2.ipynb
# 	Untitled3.ipynb
# 	Untitled4.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !rm -rf /content/drive/MyDrive/Colab_Notebooks/.git

# %%
import os
os.chdir("/content/drive/MyDrive/wrong/path/correct-subdir")
# !pwd  # Confirm you're in the right place
